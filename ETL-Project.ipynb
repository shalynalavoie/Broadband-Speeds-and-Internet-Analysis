# %% [markdown]
# # ETL Project
# ## Shalyn Lavoie | Moriah Taylor
# ### 22 May 2021

# %%
#import packages
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Load Census Data

# %%
#load census data
census_file = "./Resources/acs2017_county_data.csv"
census = pd.read_csv(census_file)
census.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   75.4   18.9     0.3  ...   0.6          1.3         2.5         25.8
# 1   83.1    9.5     0.8  ...   0.8          1.1         5.6         27.0
# 2   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 3   74.6   22.0     0.4  ...   0.3          1.7         1.5         30.0
# 4   87.4    1.5     0.3  ...   0.4          0.4         2.1         35.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0     24112         74.1        20.2           5.6         0.1           5.2
# 1     89527         80.7        12.9           6.3         0.1           5.5
# 2      8878         74.1        19.1           6.5         0.3          12.4
# 3      8171         76.0        17.4           6.3         0.3           8.2
# 4     21380         83.9        11.9           4.0         0.1           4.9
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Clean Census Data

# %%
#select CountyId, State, County, TotalPop, White, Income, IncomePerCap, Employed
census_reduced = census[["CountyId", "State", "County", "TotalPop", "White", "Income", "IncomePerCap", "Employed"]].copy()
census_reduced.head()
# Out:
#    CountyId    State          County  TotalPop  White  Income  IncomePerCap  \
# 0      1001  Alabama  Autauga County     55036   75.4   55317         27824
# 1      1003  Alabama  Baldwin County    203360   83.1   52562         29364
# 2      1005  Alabama  Barbour County     26201   45.7   33368         17561
# 3      1007  Alabama     Bibb County     22580   74.6   43404         20911
# 4      1009  Alabama   Blount County     57667   87.4   47412         22021
#
#    Employed
# 0     24112
# 1     89527
# 2      8878
# 3      8171
# 4     21380

# %% [markdown]
# ### Load Census Data

# %%
#load broadband data
broadband_file = "./Resources/broadband.csv"
broadband = pd.read_csv(broadband_file)
broadband.head()
# Out:
#    ST  COUNTY ID     COUNTY NAME BROADBAND AVAILABILITY PER FCC  \
# 0  AL       1001  Autauga County                           0.81
# 1  AL       1003  Baldwin County                           0.88
# 2  AL       1005  Barbour County                           0.59
# 3  AL       1007     Bibb County                           0.29
# 4  AL       1009   Blount County                           0.69
#
#   BROADBAND USAGE
# 0            0.28
# 1            0.30
# 2            0.18
# 3            0.07
# 4            0.09

# %% [markdown]
# ### Clean Census Data

# %%
#reduce to columns of interest
broadband_reduced = broadband[["COUNTY ID", "BROADBAND USAGE"]].copy()
broadband_reduced.head()
# Out:
#    COUNTY ID BROADBAND USAGE
# 0       1001            0.28
# 1       1003            0.30
# 2       1005            0.18
# 3       1007            0.07
# 4       1009            0.09

# %%
#rename columns
broadband_reduced = broadband_reduced.rename(columns={"COUNTY ID": "CountyId", 
                                                      "BROADBAND USAGE": "Broadband_Usage"})
broadband_reduced.head()
# Out:
#    CountyId Broadband_Usage
# 0      1001            0.28
# 1      1003            0.30
# 2      1005            0.18
# 3      1007            0.07
# 4      1009            0.09

# %% [markdown]
# ### Merge Data

# %%
#merge data
merged_data = census_reduced.merge(broadband_reduced, how="left", on="CountyId")
#make all col names lowercase
merged_data.columns = merged_data.columns.str.lower()
merged_data.head()
# Out:
#    countyid    state          county  totalpop  white  income  incomepercap  \
# 0      1001  Alabama  Autauga County     55036   75.4   55317         27824
# 1      1003  Alabama  Baldwin County    203360   83.1   52562         29364
# 2      1005  Alabama  Barbour County     26201   45.7   33368         17561
# 3      1007  Alabama     Bibb County     22580   74.6   43404         20911
# 4      1009  Alabama   Blount County     57667   87.4   47412         22021
#
#    employed broadband_usage
# 0     24112            0.28
# 1     89527            0.30
# 2      8878            0.18
# 3      8171            0.07
# 4     21380            0.09

# %% [markdown]
# ### Put Data in 3rd Normal Form

# %%
states = merged_data[["countyid", "state"]].copy()
states.head()
# Out:
#    countyid    state
# 0      1001  Alabama
# 1      1003  Alabama
# 2      1005  Alabama
# 3      1007  Alabama
# 4      1009  Alabama

# %%
county_names = merged_data[["countyid", "county"]].copy()
county_names.head()
# Out:
#    countyid          county
# 0      1001  Autauga County
# 1      1003  Baldwin County
# 2      1005  Barbour County
# 3      1007     Bibb County
# 4      1009   Blount County

# %%
counties = merged_data.drop(columns=["state", "county"]).copy()
counties.head()
# Out:
#    countyid  totalpop  white  income  incomepercap  employed broadband_usage
# 0      1001     55036   75.4   55317         27824     24112            0.28
# 1      1003    203360   83.1   52562         29364     89527            0.30
# 2      1005     26201   45.7   33368         17561      8878            0.18
# 3      1007     22580   74.6   43404         20911      8171            0.07
# 4      1009     57667   87.4   47412         22021     21380            0.09
